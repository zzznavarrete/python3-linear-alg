# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

# %%
v1 = np.array([1,1])
v2 = np.array([-1,-1])

# %%
for a in range(-10,10):
    for b in range(-10,10):
        plt.scatter(v1[0]*a + v2[0]*b, v1[1]*a + v2[1]*b,
                   marker = ".",
                   color = "orange")
        
    
plt.xlim(-30,30)
plt.ylim(-30,30)

plt.axvline(x=0, color="grey")
plt.axhline(y=0, color="grey")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Lo que nos ocurrio es que vimos 2 vectores que son [1,1], [-1, -1]
 #Entonces, cuando hicimos las combinaciones lineales, lo único que obtuvimos fue una recta
    #Esto en si mismo es un espacio, si nos abstraemos que estamos en r2 y solamente hubieramos entregado para graficar a X
    #Hubieramos obtenido lo mismo, en lugar de eso, lo que le entregamos fue elementos a r2 y obtuvimos un espacio (r1)
    #Es sólo una parte de R2

# %%
v1 = np.array([1,0])
v2 = np.array([2,-3])

# %%
for a in range(-10,10):
    for b in range(-10,10):
        plt.scatter(v1[0]*a + v2[0]*b, v1[1]*a + v2[1]*b,
                   marker = ".",
                   color = "orange")
        
    
plt.xlim(-30,30)
plt.ylim(-30,30)

plt.axvline(x=0, color="grey")
plt.axhline(y=0, color="grey")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="630">

# %%
#Nos está dando R2.. es posible con estos vectores generar el espacio 
#Lo que vemos es que, con la combinación de ellos es posible escribir cualquier elemento de este espacio
#Cuando en el elemento anteriro NO podiamos, debido a que solo nos permitía movernos a través de una recta

#En algebra lineal, siempre estamos trabajando en espacios vectoriales, lo cual no es más que números
#R, R1, R2, R3 -> Espacio escrito como vector

# %%
#Ahora veamos como R2 en verdad aparte de ser un espacio es un sub espacio de R3

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
v1 = np.array([1,0,0])
v2 = np.array([2,-3,0])

fig = plt.figure()
ax = fig.add_subplot(111,projection="3d")

for a in range(-10,10):
    for b in range(-10,10):
        ax.scatter(v1[0]*a + v2[0]*b, v1[1]*a + v2[1]*b,
                   v1[2]*a + v2[2]*b,
                   marker = ".",
                   color = "orange")
        
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Aquí vemos, que entregamos 2 vectores pero sólo fuimos capaces de generar un espacio en R2 <- comprobante lo anterior planteado

# %%
# Out:
# [False False  True]
