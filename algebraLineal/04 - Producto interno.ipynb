# %%
import numpy as np

# %%
escalar = 5.679
vector = np.array([2,3])
matriz = np.array([[1,2], [3,4], [5,6]])
print(matriz)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
from IPython.core.display import Image, display
url = 'https://i.ibb.co/5x5qNxQ/Screen-Shot-2019-11-20-at-9-06-00-PM.png'
display(Image(url, width=300, unconfined=True))


#
A = matriz * vector

# %%
from IPython.core.display import Image, display
url = 'https://i.ibb.co/bQdfLvq/Screen-Shot-2019-11-20-at-9-06-09-PM.png'
display(Image(url, width=300, unconfined=True))


#El producto interno se denota con el .dot()
B = matriz.dot(vector)

# %%
print(A)
# Out:
# [[ 2  6]
#  [ 6 12]
#  [10 18]]

# %%
print(B)
# Out:
# [ 8 18 28]
