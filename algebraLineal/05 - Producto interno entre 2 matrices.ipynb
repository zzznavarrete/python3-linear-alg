# %%
#Producto interno entre 2 matrices

# %%
import numpy as np

# %%
A = np.array([ [3,7,5], [12,2,11] ] )
B = np.array([ [3,16], [1,4], [4,22] ])

# %%
print(A.shape)
print(B.shape)
# Out:
# (2, 3)
# (3, 2)

# %%
from IPython.core.display import Image, display
url = 'https://image.jimcdn.com/app/cms/image/transf/dimension=490x10000:format=png/path/s37cc796afdd27ec2/image/i32401351e027a78f/version/1400199974/image.png'
display(Image(url, width=300, unconfined=True))



#A diferencia de la suma o de la resta, 
#la operación de la multiplicación no es posición por posición, se realiza de la siguiente manera:

# 1) Se toma la primera fila de la primera matriz y la primera columna de la segunda matriz, 
#  lo que se hace es multiplicar cada posición de la fila por cada posición de la columna, y sumar los valores 
#  resultantes de esas multiplicaciones.

#El resultado de esa suma se coloca en la primera posición de la matriz resultante.

#(3*3) + (7*1) + (5*4) = 36

# %%
from IPython.core.display import Image, display
url = 'https://image.jimcdn.com/app/cms/image/transf/dimension=490x10000:format=png/path/s37cc796afdd27ec2/image/id0fea4c25f4d2b28/version/1400200022/image.png'
display(Image(url, width=300, unconfined=True))

 #En caso de haber mas filas se toma la segunda fila, pero se sigue multiplicando por la primera columna, 
 #se hace la respectiva multiplicación y suma de valores resultantes, el resultado se guarda en la matriz
 #resultante en la posición correspondiente.  


#(3*12) + (1*2) + (4*11) = 82

# %%
from IPython.core.display import Image, display
url = 'https://image.jimcdn.com/app/cms/image/transf/dimension=490x10000:format=png/path/s37cc796afdd27ec2/image/i2a75fc88f61dd59f/version/1400200079/image.png'
display(Image(url, width=300, unconfined=True))

from IPython.core.display import Image, display
url = 'https://image.jimcdn.com/app/cms/image/transf/dimension=490x10000:format=png/path/s37cc796afdd27ec2/image/i68110cdb9fbe13f7/version/1400200250/image.png'
display(Image(url, width=300, unconfined=True))



#Si hay más columnas se repite el proceso desde el punto 1, a diferencia que las multiplicaciones
#se harán sobre la columna 2 de la segunda matriz.

# %%
#Realizamos la multiplicación en python 
C = A.dot(B)
print(C)
# Out:
# [[ 36 186]
#  [ 82 442]]

# %%
#Esto solo funciona cuando el eje Y de nuestro shape de la matriz A concuerda con el eje X del shape de la matriz B.
#Ej: Si se quisiera multiplicar las siguientes matrices, daria error:

D = np.array([ [1,2], [3,4], [5,6], [7,8] ])
E = np.array([ [9,10], [11,12], [13,14] ])

F = D.dot(E)

#not aligned: 2 (dim 1) != 3 (dim 0) <-- Es decir que la dimensión 1 no concuerda con la dimensión 0,
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6dd22bcbbb26> in <module>
#       5 E = np.array([ [9,10], [11,12], [13,14] ])
#       6
# ----> 7 F = D.dot(E)
#
# ValueError: shapes (4,2) and (3,2) not aligned: 2 (dim 1) != 3 (dim 0)

# %%
print(D.shape)
print(E.shape)
# Out:
# (4, 2)
# (3, 2)
